# %% [markdown]
# ## Evaluation of showers submitted to the Fast Calorimeter Challenge 2022

# %% [markdown]
# This is an interactive version of the file ```evaluate.py```. It can also be run directly using:
#
# ```
# python evaluate.py -i INPUT_FILE -r REFERENCE_FILE -m MODE -d DATASET --output_dir OUTPUT_DIR --source_dir SOURCE_DIR
# ```
#
# where the arguments are:
#
# - ```INPUT_FILE``` is the .hdf5 file that contains the showers to be evaluated.
#
# - ```REFERENCE_FILE``` is either the .hdf5 file that contains the showers the input is compared to, or the .pkl file that is created when the code is run for the first time. The latter contains all relevant high-level features and using it results in a faster runtime.
#
# - ```MODE``` is one of [all, avg, avg-E, hist, hist-p, hist-chi], and defaults to 'all'. 'avg' plots the average shower of all provided events; 'avg-E' plots the average shower in smaller energy ranges; 'hist' plots histograms of high-level features and saves the separation power, a measure of difference between the histogram of the provided file and the histogram of a reference in SOURCE_DIR, into a file; 'hist-p' only plots the histograms; 'hist-chi' only saves the separation power; and 'all' does all of the above.
#
# - ```DATASET``` is the name of the dataset that should be evaluated. Must be one of [1-photons, 1-pions, 2, 3].
#
# - ```OUTPUT_DIR``` is the folder in which the plots and other files will be stored. It defaults to 'evaluation_results/'.
#
# - ```SOURCE_DIR``` is the folder in which the reference .pkl will be stored. In the future, it will also be where the .hdf5 files for the classifier are saved

# %%
import os
import evaluate
import argparse
import h5py
import numpy as np

import HighLevelFeatures as HLF
# Out:
# 2023-04-02 18:35:36.688274: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-02 18:35:36.688293: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# specify to your needs:

INPUT_FILE = '../output/dataset2/v2/BNReLU_hpo105-M1/electrons_eta_20_25/selected/h5/gan.h5' # REPLACE THIS WITH YOUR GENERATED EVENTS
REFERENCE_FILE = '../input/dataset2/dataset_2_electrons_1.hdf5' # These are the GEANT evaluation events that are provided on zenodo
MODE = 'all' # not really needed here because the nb is interactive
DATASET = '2'
OUTPUT_DIR = 'evaluation_results/'
SOURCE_DIR = 'source/'

# %%
# emulating the argument parser of evaluate.py
parser_replacement = {
    'input_file': INPUT_FILE, 'reference_file': REFERENCE_FILE, 'mode': MODE, 'dataset': DATASET, 
    'output_dir': OUTPUT_DIR, 'source_dir': SOURCE_DIR, }
args = argparse.Namespace(**parser_replacement)

# %%
# reading in source file
source_file = h5py.File(args.input_file, 'r')

# checking if it has correct shape
evaluate.check_file(source_file, args)

# preparing output directory
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# preparing source directory
if not os.path.isdir(args.source_dir):
    os.makedirs(args.source_dir)

# extracting showers and energies from source file
shower, energy = evaluate.extract_shower_and_energy(source_file, args, which='input')

# creating helper class for high-level features
particle = {'1-photons': 'photon', '1-pions': 'pion',
            '2': 'electron', '3': 'electron'}[args.dataset]
hlf = HLF.HighLevelFeatures(particle, filename='binning_dataset_{}.xml'.format(args.dataset.replace('-', '_')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <module>
#       2 source_file = h5py.File(args.input_file, 'r')
#       4 # checking if it has correct shape
# ----> 5 evaluate.check_file(source_file, args)
#       7 # preparing output directory
#       8 if not os.path.isdir(args.output_dir):
#
# AttributeError: module 'evaluate' has no attribute 'check_file'

# %%
# reading in reference
if os.path.splitext(args.reference_file)[1] == '.hdf5':
    print("using .hdf5 reference")
    reference_file = h5py.File(args.reference_file, 'r')
    evaluate.check_file(reference_file, args, which='reference')
    reference_hlf = HLF.HighLevelFeatures(particle, filename='binning_dataset_{}.xml'.format(
        args.dataset.replace('-', '_')))
    reference_shower, reference_energy = evaluate.extract_shower_and_energy(reference_file, args, which='reference')
    reference_hlf.Einc = reference_energy
    evaluate.save_reference(reference_hlf, args.reference_file, args)

elif os.path.splitext(args.reference_file)[1] == '.pkl':
    print("using .pkl file for reference")
    reference_hlf = evaluate.load_reference(args.reference_file)
else:
    raise ValueError("reference_file must be .hdf5 or .pkl!")
# Out:
# using .hdf5 reference
# Checking if reference file has the correct form ...
# Found 100000 events in the file.
# Checking if reference file has the correct form: DONE
#
# Extracting showers from reference file ...
# Extracting showers from reference file: DONE.
#
# Saving file with high-level features.
# Saving file with high-level features DONE.

# %% [markdown]
# ### The cells below correspond to different evaluation MODEs and can be run independent of each other.

# %%
# evaluation mode 'avg': average of given showers
print("Plotting average shower...")
_ = hlf.DrawAverageShower(shower, filename=os.path.join(args.output_dir, 
                                                        'average_shower_dataset_{}.png'.format(args.dataset)),
                                  title="Shower average")
if hasattr(reference_hlf, 'avg_shower'):
    pass
else:
    reference_hlf.avg_shower = reference_shower.mean(axis=0, keepdims=True)
    evaluate.save_reference(reference_hlf, args.reference_file, args)
_ = hlf.DrawAverageShower(reference_hlf.avg_shower, 
                          filename=os.path.join(args.output_dir, 'reference_average_shower_dataset_{}.png'.format(
                                          args.dataset)),
                          title="Shower average reference dataset")
print("Plotting average shower: DONE.\n")
# Out:
# Plotting average shower...
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Plotting average shower: DONE.

# %%
# evaluation mode 'avg-E': average showers at different energy ranges
print("Plotting average showers for different energies ...")
if '1' in args.dataset:
    target_energies = 2**np.linspace(8, 23, 16)
    plot_title = ['shower average at E = {} MeV'.format(int(en)) for en in target_energies]
else:
    target_energies = 10**np.linspace(3, 6, 4)
    plot_title = []
    for i in range(3, 7):
        plot_title.append('shower average for E in [{}, {}] MeV'.format(10**i, 10**(i+1)))
for i in range(len(target_energies)-1):
    filename = 'average_shower_dataset_{}_E_{}.png'.format(args.dataset,
                                                                   target_energies[i])
    which_showers = ((energy >= target_energies[i]) & (energy < target_energies[i+1])).squeeze()
    _ = hlf.DrawAverageShower(shower[which_showers],
                              filename=os.path.join(args.output_dir, filename),
                              title=plot_title[i])
    if hasattr(reference_hlf, 'avg_shower_E'):
        pass
    else:
        reference_hlf.avg_shower_E = {}
    if target_energies[i] in reference_hlf.avg_shower_E:
        pass
    else:
        which_showers = ((reference_hlf.Einc >= target_energies[i]) & (reference_hlf.Einc < target_energies[i+1])).squeeze()
        reference_hlf.avg_shower_E[target_energies[i]] = reference_shower[which_showers].mean(axis=0, keepdims=True)
        evaluate.save_reference(reference_hlf, args.reference_file, args)

        _ = hlf.DrawAverageShower(reference_hlf.avg_shower_E[target_energies[i]],
                                  filename=os.path.join(args.output_dir, 'reference_'+filename),
                                  title='reference '+plot_title[i])

print("Plotting average shower for different energies: DONE.\n")
# Out:
# Plotting average showers for different energies ...
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Plotting average shower for different energies: DONE.

# %%
# evaluation mode 'hist': plotting histograms of high-level features and printing/saving the sepration power
# (equivalent to running hist-p for plotting and hist-chi for the separation power)
print("Calculating high-level features for histograms ...")
hlf.CalculateFeatures(shower)
hlf.Einc = energy

print("Calculating high-level features for histograms: DONE.\n")
if reference_hlf.E_tot is None:
    reference_hlf.CalculateFeatures(reference_shower)
    evaluate.save_reference(reference_hlf, args.reference_file, args)
print("Calculating high-level features for histograms: DONE.\n")

with open(os.path.join(args.output_dir, 'histogram_chi2_{}.txt'.format(args.dataset)), 'w') as f:
    f.write('List of chi2 of the plotted histograms, see eq. 15 of 2009.03796 for its definition.\n')
print("Plotting histograms ...")
evaluate.plot_histograms(hlf, reference_hlf, args)
print("Plotting histograms: DONE. \n")
# Out:
# Calculating high-level features for histograms ...
# Calculating high-level features for histograms: DONE.
#
# Saving file with high-level features.
# Saving file with high-level features DONE.
# Calculating high-level features for histograms: DONE.
#
# Plotting histograms ...
# Separation power of Etot / Einc histogram: 0.0005894970393222508
# Separation power of E layer 0 histogram: 7.443953022097521e-05
# Separation power of E layer 1 histogram: 0.00010201841834316259
# Separation power of E layer 2 histogram: 8.941838853914224e-05
# Separation power of E layer 3 histogram: 6.0126410714910635e-05
# Separation power of E layer 4 histogram: 8.78236461354437e-05
# Separation power of E layer 5 histogram: 7.831851533013172e-05
# Separation power of E layer 6 histogram: 0.00011273364309711817
# Separation power of E layer 7 histogram: 7.926109890219347e-05
# Separation power of E layer 8 histogram: 0.00013945603516332273
# Separation power of E layer 9 histogram: 8.628262536562437e-05
# Separation power of E layer 10 histogram: 8.87452308187964e-05
# Separation power of E layer 11 histogram: 7.430490713074002e-05
# Separation power of E layer 12 histogram: 6.545178193748607e-05
# Separation power of E layer 13 histogram: 8.5785012505417e-05
# Separation power of E layer 14 histogram: 9.920804856927762e-05
# Separation power of E layer 15 histogram: 4.776986228652571e-05
# Separation power of E layer 16 histogram: 9.808751513461317e-05
# Separation power of E layer 17 histogram: 9.17836068661247e-05
# Separation power of E layer 18 histogram: 9.378271450434698e-05
# Separation power of E layer 19 histogram: 0.00010833392105702143
# Separation power of E layer 20 histogram: 6.748592683284082e-05
# Separation power of E layer 21 histogram: 0.00017166959309766457
# Separation power of E layer 22 histogram: 0.00014872429921271828
# Separation power of E layer 23 histogram: 0.00013161681607542526
# Separation power of E layer 24 histogram: 0.0001245715073776051
# Separation power of E layer 25 histogram: 4.7611042956169257e-05
# Separation power of E layer 26 histogram: 0.00011162414886115745
# Separation power of E layer 27 histogram: 7.396324277438891e-05
# Separation power of E layer 28 histogram: 0.00010822310401138213
# Separation power of E layer 29 histogram: 5.626516000478163e-05
# Separation power of E layer 30 histogram: 7.779518217008774e-05
# Separation power of E layer 31 histogram: 6.889906385826882e-05
# Separation power of E layer 32 histogram: 4.833808557459818e-05
# Separation power of E layer 33 histogram: 5.3184923597142537e-05
# Separation power of E layer 34 histogram: 5.2049625749067806e-05
# Separation power of E layer 35 histogram: 4.768030188733382e-05
# Separation power of E layer 36 histogram: 2.7075072191987388e-05
# Separation power of E layer 37 histogram: 1.5577888972007372e-05
# Separation power of E layer 38 histogram: 1.3254281498939815e-05
# Separation power of E layer 39 histogram: 2.226359457481737e-05
# Separation power of E layer 40 histogram: 2.078273842956527e-05
# Separation power of E layer 41 histogram: 3.103682908554066e-05
# Separation power of E layer 42 histogram: 3.45750961853525e-05
# Separation power of E layer 43 histogram: 2.5216942559249147e-05
# Separation power of E layer 44 histogram: 4.8749070592128006e-05
# Separation power of EC Eta layer 0 histogram: 0.0005473692907741618
# Separation power of EC Eta layer 1 histogram: 0.00047189917316840314
# Separation power of EC Eta layer 2 histogram: 0.0004707724064968534
# Separation power of EC Eta layer 3 histogram: 0.0004816007168240121
# Separation power of EC Eta layer 4 histogram: 0.0004760089078651034
# Separation power of EC Eta layer 5 histogram: 0.00038708775875159583
# Separation power of EC Eta layer 6 histogram: 0.000418859009523661
# Separation power of EC Eta layer 7 histogram: 0.00046056979333767477
# Separation power of EC Eta layer 8 histogram: 0.0005004510321260052
# Separation power of EC Eta layer 9 histogram: 0.0005324171515717594
# Separation power of EC Eta layer 10 histogram: 0.0005919016462849325
# Separation power of EC Eta layer 11 histogram: 0.0005930821220366476
# Separation power of EC Eta layer 12 histogram: 0.0005208119074010644
# Separation power of EC Eta layer 13 histogram: 0.0005061776302071181
# Separation power of EC Eta layer 14 histogram: 0.0005129017574591536
# Separation power of EC Eta layer 15 histogram: 0.0004996432874924143
# Separation power of EC Eta layer 16 histogram: 0.0004905994702758178
# Separation power of EC Eta layer 17 histogram: 0.0005262506118521968
# Separation power of EC Eta layer 18 histogram: 0.0006214008380678074
# Separation power of EC Eta layer 19 histogram: 0.0004981333275418348
# Separation power of EC Eta layer 20 histogram: 0.0005219506190675982
# Separation power of EC Eta layer 21 histogram: 0.0004990402291513755
# Separation power of EC Eta layer 22 histogram: 0.0004440177458277964
# Separation power of EC Eta layer 23 histogram: 0.0005663941893529909
# Separation power of EC Eta layer 24 histogram: 0.00045671870426523614
# Separation power of EC Eta layer 25 histogram: 0.0004884170582106407
# Separation power of EC Eta layer 26 histogram: 0.00039782532041340504
# Separation power of EC Eta layer 27 histogram: 0.0005367537169098652
# Separation power of EC Eta layer 28 histogram: 0.0005025466868498169
# Separation power of EC Eta layer 29 histogram: 0.0006314329747586876
# Separation power of EC Eta layer 30 histogram: 0.0006651677134508706
# Separation power of EC Eta layer 31 histogram: 0.0005129177318238664
# Separation power of EC Eta layer 32 histogram: 0.0005710142716712052
# Separation power of EC Eta layer 33 histogram: 0.000581257536012758
# Separation power of EC Eta layer 34 histogram: 0.000534032587665133
# Separation power of EC Eta layer 35 histogram: 0.0004953356237541801
# Separation power of EC Eta layer 36 histogram: 0.00048023869056610643
# Separation power of EC Eta layer 37 histogram: 0.0004255963040598775
# Separation power of EC Eta layer 38 histogram: 0.0005627399908275565
# Separation power of EC Eta layer 39 histogram: 0.0004616918235964678
# Separation power of EC Eta layer 40 histogram: 0.0006177011103693165
# Separation power of EC Eta layer 41 histogram: 0.000466908033520571
# Separation power of EC Eta layer 42 histogram: 0.0004361775502875018
# Separation power of EC Eta layer 43 histogram: 0.00047643974493725673
# Separation power of EC Eta layer 44 histogram: 0.0006322578551020271
# Separation power of EC Phi layer 0 histogram: 0.00047340129509899545
# Separation power of EC Phi layer 1 histogram: 0.00045639549806697174
# Separation power of EC Phi layer 2 histogram: 0.0005329312958656193
# Separation power of EC Phi layer 3 histogram: 0.00038828038176729656
# Separation power of EC Phi layer 4 histogram: 0.0004682970768353922
# Separation power of EC Phi layer 5 histogram: 0.0004838262380455425
# Separation power of EC Phi layer 6 histogram: 0.000552493551315328
# Separation power of EC Phi layer 7 histogram: 0.0004476200674584515
# Separation power of EC Phi layer 8 histogram: 0.00043650055731673815
# Separation power of EC Phi layer 9 histogram: 0.000642009209850828
# Separation power of EC Phi layer 10 histogram: 0.0005437837316277341
# Separation power of EC Phi layer 11 histogram: 0.0005977243525924574
# Separation power of EC Phi layer 12 histogram: 0.0003832591298894559
# Separation power of EC Phi layer 13 histogram: 0.0005500004846986803
# Separation power of EC Phi layer 14 histogram: 0.000502966842374278
# Separation power of EC Phi layer 15 histogram: 0.0004917246935091717
# Separation power of EC Phi layer 16 histogram: 0.000427441883018426
# Separation power of EC Phi layer 17 histogram: 0.00047323895386444106
# Separation power of EC Phi layer 18 histogram: 0.0005522591067801321
# Separation power of EC Phi layer 19 histogram: 0.0005923770506726009
# Separation power of EC Phi layer 20 histogram: 0.00044797330769708624
# Separation power of EC Phi layer 21 histogram: 0.000488302807944058
# Separation power of EC Phi layer 22 histogram: 0.0005363789200493286
# Separation power of EC Phi layer 23 histogram: 0.0005155702880105482
# Separation power of EC Phi layer 24 histogram: 0.0004557016120863681
# Separation power of EC Phi layer 25 histogram: 0.0006013349283654456
# Separation power of EC Phi layer 26 histogram: 0.0005730391893710942
# Separation power of EC Phi layer 27 histogram: 0.0003728871862763908
# Separation power of EC Phi layer 28 histogram: 0.0005164617907629893
# Separation power of EC Phi layer 29 histogram: 0.0005470347580006633
# Separation power of EC Phi layer 30 histogram: 0.0005120968237999225
# Separation power of EC Phi layer 31 histogram: 0.00042607013933174906
# Separation power of EC Phi layer 32 histogram: 0.0005034095474710024
# Separation power of EC Phi layer 33 histogram: 0.0005655612046289981
# Separation power of EC Phi layer 34 histogram: 0.000580752533990583
# Separation power of EC Phi layer 35 histogram: 0.0006407277440868604
# Separation power of EC Phi layer 36 histogram: 0.0005433551729186483
# Separation power of EC Phi layer 37 histogram: 0.0005810113472425945
# Separation power of EC Phi layer 38 histogram: 0.0005811706899717539
# Separation power of EC Phi layer 39 histogram: 0.0005819811451598851
# Separation power of EC Phi layer 40 histogram: 0.0005121027727607201
# Separation power of EC Phi layer 41 histogram: 0.0005285166041730031
# Separation power of EC Phi layer 42 histogram: 0.000570438972732989
# Separation power of EC Phi layer 43 histogram: 0.0005163814289509245
# Separation power of EC Phi layer 44 histogram: 0.00048616605324559354
# Separation power of Width Eta layer 0 histogram: 0.00047263828165863765
# Separation power of Width Eta layer 1 histogram: 0.00043626061298440976
# Separation power of Width Eta layer 2 histogram: 0.0003809020654860172
# Separation power of Width Eta layer 3 histogram: 0.0003299871672825117
# Separation power of Width Eta layer 4 histogram: 0.0004115390790828298
# Separation power of Width Eta layer 5 histogram: 0.0005330651468110181
# Separation power of Width Eta layer 6 histogram: 0.0004940444235156262
# Separation power of Width Eta layer 7 histogram: 0.0005314516881285635
# Separation power of Width Eta layer 8 histogram: 0.00036881928411201234
# Separation power of Width Eta layer 9 histogram: 0.0003982418267969822
# Separation power of Width Eta layer 10 histogram: 0.0005643419347466138
# Separation power of Width Eta layer 11 histogram: 0.00041336972543000325
# Separation power of Width Eta layer 12 histogram: 0.00046449104101545257
# Separation power of Width Eta layer 13 histogram: 0.0005167830380911519
# Separation power of Width Eta layer 14 histogram: 0.0006009238213022783
# Separation power of Width Eta layer 15 histogram: 0.0004970425710843593
# Separation power of Width Eta layer 16 histogram: 0.00047403737837807476
# Separation power of Width Eta layer 17 histogram: 0.0004935692197590638
# Separation power of Width Eta layer 18 histogram: 0.000491518871207286
# Separation power of Width Eta layer 19 histogram: 0.000563343781812879
# Separation power of Width Eta layer 20 histogram: 0.0005221378804711636
# Separation power of Width Eta layer 21 histogram: 0.0005741660673680106
# Separation power of Width Eta layer 22 histogram: 0.0005582543618712225
# Separation power of Width Eta layer 23 histogram: 0.0005644041241699531
# Separation power of Width Eta layer 24 histogram: 0.0006282976805662115
# Separation power of Width Eta layer 25 histogram: 0.00034783017606015575
# Separation power of Width Eta layer 26 histogram: 0.0004079848629511923
# Separation power of Width Eta layer 27 histogram: 0.0006159505266612131
# Separation power of Width Eta layer 28 histogram: 0.0004016050199230628
# Separation power of Width Eta layer 29 histogram: 0.0004966492145193351
# Separation power of Width Eta layer 30 histogram: 0.0006587158553789572
# Separation power of Width Eta layer 31 histogram: 0.0004888532897178418
# Separation power of Width Eta layer 32 histogram: 0.0004649926643004927
# Separation power of Width Eta layer 33 histogram: 0.0004977303358715941
# Separation power of Width Eta layer 34 histogram: 0.0005281762450376465
# Separation power of Width Eta layer 35 histogram: 0.0004983694346350118
# Separation power of Width Eta layer 36 histogram: 0.0004664913691664397
# Separation power of Width Eta layer 37 histogram: 0.0005128046890799115
# Separation power of Width Eta layer 38 histogram: 0.0004973551770883825
# Separation power of Width Eta layer 39 histogram: 0.00047218217766969496
# Separation power of Width Eta layer 40 histogram: 0.0005681625736153671
# Separation power of Width Eta layer 41 histogram: 0.0006563525194399351
# Separation power of Width Eta layer 42 histogram: 0.00043969617410463023
# Separation power of Width Eta layer 43 histogram: 0.0006049918208709267
# Separation power of Width Eta layer 44 histogram: 0.0005305132702089632
# Separation power of Width Phi layer 0 histogram: 0.0005430787286412367
# Separation power of Width Phi layer 1 histogram: 0.00044616187347061684
# Separation power of Width Phi layer 2 histogram: 0.0004904257016055528
# Separation power of Width Phi layer 3 histogram: 0.0004242341745280305
# Separation power of Width Phi layer 4 histogram: 0.00033198924135685023
# Separation power of Width Phi layer 5 histogram: 0.0004162440987033069
# Separation power of Width Phi layer 6 histogram: 0.0003774551800798266
# Separation power of Width Phi layer 7 histogram: 0.0004931873854141184
# Separation power of Width Phi layer 8 histogram: 0.00036857304875861306
# Separation power of Width Phi layer 9 histogram: 0.00040466130628704597
# Separation power of Width Phi layer 10 histogram: 0.0003731244596007941
# Separation power of Width Phi layer 11 histogram: 0.0004672251564809408
# Separation power of Width Phi layer 12 histogram: 0.0005079941229346387
# Separation power of Width Phi layer 13 histogram: 0.0004986302502721138
# Separation power of Width Phi layer 14 histogram: 0.0004906132924199548
# Separation power of Width Phi layer 15 histogram: 0.0005417663608482925
# Separation power of Width Phi layer 16 histogram: 0.00036526151562874177
# Separation power of Width Phi layer 17 histogram: 0.0005048381695914035
# Separation power of Width Phi layer 18 histogram: 0.0004884355926942528
# Separation power of Width Phi layer 19 histogram: 0.0007272901667866984
# Separation power of Width Phi layer 20 histogram: 0.0005235510605877951
# Separation power of Width Phi layer 21 histogram: 0.0005462297651157129
# Separation power of Width Phi layer 22 histogram: 0.0003721988150859837
# Separation power of Width Phi layer 23 histogram: 0.000369358779186707
# Separation power of Width Phi layer 24 histogram: 0.0004663537795847902
# Separation power of Width Phi layer 25 histogram: 0.0004065215754492443
# Separation power of Width Phi layer 26 histogram: 0.0005506613485808644
# Separation power of Width Phi layer 27 histogram: 0.0005364507856116082
# Separation power of Width Phi layer 28 histogram: 0.0005698960005791174
# Separation power of Width Phi layer 29 histogram: 0.0005621963794848051
# Separation power of Width Phi layer 30 histogram: 0.0003885517332191419
# Separation power of Width Phi layer 31 histogram: 0.0004293474386641836
# Separation power of Width Phi layer 32 histogram: 0.00042661622655343264
# Separation power of Width Phi layer 33 histogram: 0.0006554289237954017
# Separation power of Width Phi layer 34 histogram: 0.0005394209922926949
# Separation power of Width Phi layer 35 histogram: 0.0005047713062019574
# Separation power of Width Phi layer 36 histogram: 0.0005133949891658726
# Separation power of Width Phi layer 37 histogram: 0.00048165904011928014
# Separation power of Width Phi layer 38 histogram: 0.0005465287251040004
# Separation power of Width Phi layer 39 histogram: 0.000485401130680107
# Separation power of Width Phi layer 40 histogram: 0.0005288883382042021
# Separation power of Width Phi layer 41 histogram: 0.0006145511027434444
# Separation power of Width Phi layer 42 histogram: 0.0005244414374662136
# Separation power of Width Phi layer 43 histogram: 0.0006686267679355603
# Separation power of Width Phi layer 44 histogram: 0.000516809146867539
# Plotting histograms: DONE.
